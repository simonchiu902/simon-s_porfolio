# %% [markdown]
# ### (2) Market Basket Analysis

# %% [markdown]
# Problem Statement: Our merchandising team wishes to introduce bundles for all products on our website to increase the average basket size when customers make an online purchase. Describe clearly how you will work on this problem, and the insights you can draw from this analysis.

# %% [markdown]
# Deliverables:
# Provide a clear explanation of your methodology. This includes:
#
# (1) Listing down the features you used (if any).
#
# (2) Explanation of how your proposed approach could be used to solve this business problem.
#
# (3) Highlighting the limitations and caveats of your approach.
#
# (4) What are the business insights that you recommend based on your findings?

# %% [markdown]
# # Table of Content

# %% [markdown]
# 1.[Data Preprocessing](#dp)

# %% [markdown]
# 2.[FP-Growth Algorithm](#fp)

# %% [markdown]
# 3.[Business Insight](#bi)

# %% [markdown]
# 4.[Limitation](#l)

# %% [markdown]
# ### 1.Data Preprocessing <a id="dp"></a>

# %% [markdown]
# 1. The problem focus on the website, so we first filter the transactions on the website.
#
#
# 2. Since the distribution of sku_idr_sku is highly positive skewed, which means most sku_idr_sku only appear few times in the dataset, we will exclude those infrequent sku_idr_sku for better pattern mining.
#
#
# 3. In original dataset, each row only contains one sku_idr_sku so we need to first group by the_transaction_id to find out products in the same basket.
#
#
# 4. In a basket, same sku_idr_sku may appear multiple times, so we use set to remove duplication.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Recruitment_Transactions_ToBeDistributed.csv')

# %%
#remove Unnamed: 0 column
df = df.iloc[:,1:]

# %%
#column preprocessing(change columns into proper data type)
#Convert the_date_transaction column to datetime
df['the_date_transaction'] = pd.to_datetime(df['the_date_transaction'])
#only include rows with f_qty_item and f_to_tax_in not equal to 0
df=df[(df['f_qty_item'] != 0) & (df['f_to_tax_in'] != 0)]
#only include online transaction
df = df[df['the_to_type']=='online']

# %%
df.shape
# Out:
# (533688, 10)

# %%
#the distribution is highly skewed, most sku_idr_sku only appear few times
sku_counts = df['sku_idr_sku'].value_counts()
plt.hist(sku_counts.values, bins=50)
plt.xlabel('Frequency')
plt.ylabel('Number of SKUs')
plt.show()

# %%
#if we only include sku_counts >= 100, the distribution pattern can be clearer
#100 here is a hyperparameter, which can be changed based on domain knowledge
plt.hist(sku_counts[sku_counts >= 100].values, bins=50)
plt.xlabel('Frequency')
plt.ylabel('Number of SKUs')
plt.show()

# %%
#To perform pattern mining, the current dataset is too big, which may encounter memory issue 
#Also, it doesn't make sense to include infrequent products into analysis
#So we first exclude those rows with sku_idr_sku that appears less than 100
sku_counts = df['sku_idr_sku'].value_counts()
valid_skus = sku_counts[sku_counts >= 100].index
filtered_df = df[df['sku_idr_sku'].isin(valid_skus)]

# %%
#there are 1068 valid products
valid_skus.shape
# Out:
# (1068,)

# %%
#after filtering, the new dataset has a 256782 rows
filtered_df.shape
# Out:
# (256782, 10)

# %%
#To know what products are in the same basket, we need to first transform df 
new_df = filtered_df.groupby('the_transaction_id')['sku_idr_sku'].agg(list).reset_index()

# %%
#there may be some duplicate in the list, for example, the first row has multiple 7200852 in the list
new_df
# Out:
#                          the_transaction_id  \
# 0       7-1034-1034-20200701114220-102-6102
# 1       7-1034-1034-20200701114619-102-6103
# 2       7-1034-1034-20200701115438-102-6106
# 3       7-1034-1034-20200701115845-102-6107
# 4       7-1034-1034-20200701120319-102-6108
# ...                                     ...
# 130054    7-969-969-20201231213532-215-9561
# 130055     7-969-969-20201231213922-216-174
# 130056    7-969-969-20201231214031-215-9562
# 130057    7-969-969-20201231214031-215-9563
# 130058    7-969-969-20201231222532-215-9564
#
#                                               sku_idr_sku
# 0       [7200852, 7200852, 7200852, 7200852, 7200852, ...
# 1       [7200852, 7200852, 7200852, 7200852, 7200852, ...
# 2                             [7364235, 7238085, 7116403]
# 3                                               [2024828]
# 4                                               [7351035]
# ...                                                   ...
# 130054                                          [1769129]
# 130055                                          [5143720]
# 130056                                          [7008837]
# 130057                                          [1769129]
# 130058                                          [7212377]
#
# [130059 rows x 2 columns]

# %%
# To exclue the duplication, we can use set to make 'sku_idr_sku' unique
new_df['sku_idr_sku'] = new_df['sku_idr_sku'].apply(lambda x: list(set(x)))

# %%
new_df
# Out:
#                          the_transaction_id                  sku_idr_sku
# 0       7-1034-1034-20200701114220-102-6102                    [7200852]
# 1       7-1034-1034-20200701114619-102-6103                    [7200852]
# 2       7-1034-1034-20200701115438-102-6106  [7364235, 7238085, 7116403]
# 3       7-1034-1034-20200701115845-102-6107                    [2024828]
# 4       7-1034-1034-20200701120319-102-6108                    [7351035]
# ...                                     ...                          ...
# 130054    7-969-969-20201231213532-215-9561                    [1769129]
# 130055     7-969-969-20201231213922-216-174                    [5143720]
# 130056    7-969-969-20201231214031-215-9562                    [7008837]
# 130057    7-969-969-20201231214031-215-9563                    [1769129]
# 130058    7-969-969-20201231222532-215-9564                    [7212377]
#
# [130059 rows x 2 columns]

# %% [markdown]
# ### 2.FP-Growth Algorithm <a id="fp"></a>

# %% [markdown]
# 1. To increase the basket size, one way is to find the association rules and recommend products that customers may like to them.
#
#
# 2. There are several algorithms available for association rule mining. The most famous one is Apriori Algorithm, which generates candidate itemsets of increasing size, and prun those that do not meet the minimum support threshold. However for big dataset, it may be less efficient.
#
#
# 3. To solve above problem, I used FP-Growth Algorithm. This alogorithm works by building a tree structure to represent the transactions, and using this tree to efficiently find frequent itemsets.
#
#
# 4. Some hyperparameters are set and they can be adjusted based on domain knowledge. For example, in below code, minimum support count is set to be 0.05% of total transactions; minimum confidence threshold is set to be 0.5, which means when Antecedent appears, ther is 50% chance that Consequent also appears.

# %%
import pyfpgrowth 

# mine frequent itemsets
frequent_itemsets = pyfpgrowth.find_frequent_patterns(
    transactions=new_df['sku_idr_sku'],
    support_threshold=new_df.shape[0]*0.0005  # minimum support count = 0.05% of total transactions
)
for itemset, support in frequent_itemsets.items():
    print('Itemset: {} \t Support: {}'.format(itemset, support))
# Out:
# Itemset: (1819587,) 	 Support: 75
# Itemset: (1904222,) 	 Support: 77
# Itemset: (7226527,) 	 Support: 78
# Itemset: (1679832,) 	 Support: 80
# Itemset: (18983,) 	 Support: 81
# Itemset: (2434407,) 	 Support: 81
# Itemset: (7004659,) 	 Support: 81
# Itemset: (395214,) 	 Support: 82
# Itemset: (622484,) 	 Support: 84
# Itemset: (6999523,) 	 Support: 86
# Itemset: (7114924,) 	 Support: 87
# Itemset: (905216,) 	 Support: 87
# Itemset: (7217474,) 	 Support: 89
# Itemset: (1000706,) 	 Support: 90
# Itemset: (7361976,) 	 Support: 92
# Itemset: (1375184,) 	 Support: 92
# Itemset: (6999866,) 	 Support: 92
# Itemset: (7363713,) 	 Support: 93
# Itemset: (1455489,) 	 Support: 94
# Itemset: (1164876,) 	 Support: 96
# Itemset: (6968678,) 	 Support: 97
# Itemset: (7179441,) 	 Support: 97
# Itemset: (7002721,) 	 Support: 98
# Itemset: (7275246,) 	 Support: 98
# Itemset: (7369847,) 	 Support: 98
# Itemset: (2423946,) 	 Support: 98
# Itemset: (6988590,) 	 Support: 98
# Itemset: (870286,) 	 Support: 99
# Itemset: (7271636,) 	 Support: 99
# Itemset: (6981810,) 	 Support: 99
# Itemset: (7334882,) 	 Support: 99
# Itemset: (161540,) 	 Support: 99
# Itemset: (6990172,) 	 Support: 99
# Itemset: (1902622,) 	 Support: 99
# Itemset: (1570021,) 	 Support: 100
# Itemset: (7004959,) 	 Support: 100
# Itemset: (2154205,) 	 Support: 100
# Itemset: (417666,) 	 Support: 100
# Itemset: (7334463,) 	 Support: 100
# Itemset: (7244098,) 	 Support: 100
# Itemset: (882110,) 	 Support: 100
# Itemset: (7270021,) 	 Support: 100
# Itemset: (7010637,) 	 Support: 100
# Itemset: (669146,) 	 Support: 100
# Itemset: (842791,) 	 Support: 100
# Itemset: (883948,) 	 Support: 100
# Itemset: (137748,) 	 Support: 100
# Itemset: (2483509,) 	 Support: 100
# Itemset: (7347867,) 	 Support: 100
# Itemset: (7163015,) 	 Support: 100
# Itemset: (1669349,) 	 Support: 100
# Itemset: (7234520,) 	 Support: 100
# Itemset: (1686060,) 	 Support: 100
# Itemset: (7174405,) 	 Support: 100
# Itemset: (123680,) 	 Support: 100
# Itemset: (2083538,) 	 Support: 100
# Itemset: (7228057,) 	 Support: 100
# Itemset: (2459652,) 	 Support: 100
# Itemset: (6839120,) 	 Support: 100
# Itemset: (7115627,) 	 Support: 101
# Itemset: (7269201,) 	 Support: 101
# Itemset: (7328335,) 	 Support: 101
# Itemset: (7210264,) 	 Support: 101
# Itemset: (2435302,) 	 Support: 101
# Itemset: (2084567,) 	 Support: 101
# Itemset: (7210471,) 	 Support: 101
# Itemset: (1700600,) 	 Support: 101
# Itemset: (7209204,) 	 Support: 101
# Itemset: (6987191,) 	 Support: 101
# Itemset: (6967119,) 	 Support: 101
# Itemset: (7342279,) 	 Support: 101
# Itemset: (7234720,) 	 Support: 102
# Itemset: (7384360,) 	 Support: 102
# Itemset: (7210594,) 	 Support: 102
# Itemset: (7146769,) 	 Support: 102
# Itemset: (7205184,) 	 Support: 102
# Itemset: (7355218,) 	 Support: 102
# Itemset: (7274345,) 	 Support: 102
# Itemset: (1990867,) 	 Support: 102
# Itemset: (7162590,) 	 Support: 103
# Itemset: (7331899,) 	 Support: 103
# Itemset: (2051986,) 	 Support: 103
# Itemset: (7285928,) 	 Support: 103
# Itemset: (7149349,) 	 Support: 103
# Itemset: (6992056,) 	 Support: 103
# Itemset: (7146144,) 	 Support: 103
# Itemset: (880572,) 	 Support: 103
# Itemset: (7203922,) 	 Support: 103
# Itemset: (7224760,) 	 Support: 103
# Itemset: (7220100,) 	 Support: 103
# Itemset: (988138,) 	 Support: 103
# Itemset: (2257745,) 	 Support: 103
# Itemset: (1791531,) 	 Support: 103
# Itemset: (7121146,) 	 Support: 103
# Itemset: (7000244,) 	 Support: 103
# Itemset: (6980329,) 	 Support: 103
# Itemset: (1007256,) 	 Support: 103
# Itemset: (7202088,) 	 Support: 104
# Itemset: (7017367,) 	 Support: 104
# Itemset: (1607521,) 	 Support: 104
# Itemset: (7278911,) 	 Support: 104
# Itemset: (2017013,) 	 Support: 104
# Itemset: (7363021,) 	 Support: 104
# Itemset: (7224848,) 	 Support: 104
# Itemset: (7266534,) 	 Support: 104
# Itemset: (1343122,) 	 Support: 105
# Itemset: (7339645,) 	 Support: 105
# Itemset: (2778636,) 	 Support: 105
# Itemset: (2039644,) 	 Support: 105
# Itemset: (7328761,) 	 Support: 105
# Itemset: (2129050,) 	 Support: 105
# Itemset: (505740,) 	 Support: 105
# Itemset: (7013579,) 	 Support: 105
# Itemset: (7240687,) 	 Support: 105
# Itemset: (7257734,) 	 Support: 105
# Itemset: (7231458,) 	 Support: 105
# Itemset: (7203903,) 	 Support: 105
# Itemset: (7285454,) 	 Support: 105
# Itemset: (7331726,) 	 Support: 106
# Itemset: (7368869,) 	 Support: 106
# Itemset: (6963777,) 	 Support: 106
# Itemset: (2268632,) 	 Support: 106
# Itemset: (1816290,) 	 Support: 106
# Itemset: (6956962,) 	 Support: 106
# Itemset: (2404546,) 	 Support: 106
# Itemset: (7339118,) 	 Support: 106
# Itemset: (7366947,) 	 Support: 106
# Itemset: (7208712,) 	 Support: 106
# Itemset: (2447852,) 	 Support: 106
# Itemset: (7327908,) 	 Support: 106
# Itemset: (7223632,) 	 Support: 106
# Itemset: (7216687,) 	 Support: 106
# Itemset: (1888549,) 	 Support: 106
# Itemset: (7370915,) 	 Support: 106
# Itemset: (7292118,) 	 Support: 106
# Itemset: (2480903,) 	 Support: 107
# Itemset: (7209087,) 	 Support: 107
# Itemset: (7363866,) 	 Support: 107
# Itemset: (1985344,) 	 Support: 107
# Itemset: (6958426,) 	 Support: 107
# Itemset: (7357798,) 	 Support: 107
# Itemset: (7226799,) 	 Support: 107
# Itemset: (7198412,) 	 Support: 107
# Itemset: (7197856,) 	 Support: 107
# Itemset: (7419880,) 	 Support: 107
# Itemset: (7364822,) 	 Support: 107
# Itemset: (7207931,) 	 Support: 107
# Itemset: (7212711,) 	 Support: 107
# Itemset: (7344929,) 	 Support: 107
# Itemset: (7166600,) 	 Support: 107
# Itemset: (7263162,) 	 Support: 108
# Itemset: (7215793,) 	 Support: 108
# Itemset: (7248263,) 	 Support: 108
# Itemset: (7365486,) 	 Support: 108
# Itemset: (7335726,) 	 Support: 108
# Itemset: (7355060,) 	 Support: 108
# Itemset: (315856,) 	 Support: 109
# Itemset: (7270296,) 	 Support: 109
# Itemset: (6985571,) 	 Support: 109
# Itemset: (1968824,) 	 Support: 109
# Itemset: (7220582,) 	 Support: 109
# Itemset: (2419571,) 	 Support: 109
# Itemset: (2101894,) 	 Support: 109
# Itemset: (7171704,) 	 Support: 109
# Itemset: (7355135,) 	 Support: 109
# Itemset: (7212440,) 	 Support: 109
# Itemset: (7366708,) 	 Support: 109
# Itemset: (7115793,) 	 Support: 109
# Itemset: (1635730,) 	 Support: 109
# Itemset: (1410382,) 	 Support: 109
# Itemset: (7244818,) 	 Support: 109
# Itemset: (7097070,) 	 Support: 109
# Itemset: (1933299,) 	 Support: 110
# Itemset: (2066934,) 	 Support: 110
# Itemset: (7151260,) 	 Support: 110
# Itemset: (7201382,) 	 Support: 110
# Itemset: (1001612,) 	 Support: 110
# Itemset: (1001612, 2461867) 	 Support: 91
# Itemset: (7227516,) 	 Support: 110
# Itemset: (7164281,) 	 Support: 110
# Itemset: (2292172,) 	 Support: 110
# Itemset: (7010470,) 	 Support: 111
# Itemset: (7119536,) 	 Support: 111
# Itemset: (6982219,) 	 Support: 111
# Itemset: (7014440,) 	 Support: 111
# Itemset: (7011829,) 	 Support: 111
# Itemset: (7206098,) 	 Support: 111
# Itemset: (7284086,) 	 Support: 111
# Itemset: (540452,) 	 Support: 111
# Itemset: (6978557,) 	 Support: 111
# Itemset: (6988587,) 	 Support: 111
# Itemset: (7341839,) 	 Support: 111
# Itemset: (7230647,) 	 Support: 111
# Itemset: (1365969,) 	 Support: 111
# Itemset: (7219260,) 	 Support: 111
# Itemset: (7227996,) 	 Support: 111
# Itemset: (7436074,) 	 Support: 111
# Itemset: (1983136,) 	 Support: 111
# Itemset: (6995903,) 	 Support: 112
# Itemset: (1399078,) 	 Support: 112
# Itemset: (7341938,) 	 Support: 112
# Itemset: (2434304,) 	 Support: 112
# Itemset: (7382884,) 	 Support: 112
# Itemset: (2411478,) 	 Support: 112
# Itemset: (6977568,) 	 Support: 112
# Itemset: (7331623,) 	 Support: 113
# Itemset: (7256298,) 	 Support: 113
# Itemset: (7209407,) 	 Support: 113
# Itemset: (2345994,) 	 Support: 113
# Itemset: (7013282,) 	 Support: 113
# Itemset: (518221,) 	 Support: 113
# Itemset: (7243976,) 	 Support: 114
# Itemset: (7416104,) 	 Support: 114
# Itemset: (1430178,) 	 Support: 114
# Itemset: (7224235,) 	 Support: 114
# Itemset: (7384023,) 	 Support: 114
# Itemset: (870918,) 	 Support: 115
# Itemset: (7347290,) 	 Support: 115
# Itemset: (6982057,) 	 Support: 115
# Itemset: (7202942,) 	 Support: 115
# Itemset: (7114907,) 	 Support: 115
# Itemset: (7250877,) 	 Support: 115
# Itemset: (7003147,) 	 Support: 115
# Itemset: (7343660,) 	 Support: 115
# Itemset: (6978828,) 	 Support: 115
# Itemset: (7211127,) 	 Support: 115
# Itemset: (1531088,) 	 Support: 115
# Itemset: (2104356,) 	 Support: 115
# Itemset: (6957989,) 	 Support: 115
# Itemset: (1909287,) 	 Support: 115
# Itemset: (6987602,) 	 Support: 115
# Itemset: (1321429,) 	 Support: 115
# Itemset: (2399173,) 	 Support: 115
# Itemset: (7258663,) 	 Support: 115
# Itemset: (7254806,) 	 Support: 116
# Itemset: (7164662,) 	 Support: 116
# Itemset: (7367483,) 	 Support: 116
# Itemset: (7008585,) 	 Support: 116
# Itemset: (1072671,) 	 Support: 116
# Itemset: (7208759,) 	 Support: 116
# Itemset: (2434110,) 	 Support: 116
# Itemset: (2348395,) 	 Support: 117
# Itemset: (1557445,) 	 Support: 117
# Itemset: (729959,) 	 Support: 117
# Itemset: (7095796,) 	 Support: 117
# Itemset: (7364148,) 	 Support: 117
# Itemset: (7204713,) 	 Support: 117
# Itemset: (1676312,) 	 Support: 117
# Itemset: (6920325,) 	 Support: 117
# Itemset: (2096178,) 	 Support: 118
# Itemset: (810050,) 	 Support: 118
# Itemset: (6980602,) 	 Support: 118
# Itemset: (7008850,) 	 Support: 118
# Itemset: (7317793,) 	 Support: 118
# Itemset: (7216706,) 	 Support: 118
# Itemset: (7205484,) 	 Support: 118
# Itemset: (1253590,) 	 Support: 118
# Itemset: (1371590,) 	 Support: 118
# Itemset: (2137874,) 	 Support: 118
# Itemset: (1260871,) 	 Support: 118
# Itemset: (6959693,) 	 Support: 118
# Itemset: (1011354,) 	 Support: 119
# Itemset: (7348030,) 	 Support: 119
# Itemset: (7223410,) 	 Support: 119
# Itemset: (629366,) 	 Support: 119
# Itemset: (2414888,) 	 Support: 119
# Itemset: (7200525,) 	 Support: 119
# Itemset: (6982426,) 	 Support: 119
# Itemset: (6824916,) 	 Support: 119
# Itemset: (7226433,) 	 Support: 119
# Itemset: (7144972,) 	 Support: 120
# Itemset: (6988865,) 	 Support: 120
# Itemset: (910784,) 	 Support: 120
# Itemset: (1942838,) 	 Support: 120
# Itemset: (7275085,) 	 Support: 120
# Itemset: (7365593,) 	 Support: 120
# Itemset: (7248827,) 	 Support: 120
# Itemset: (7209679,) 	 Support: 120
# Itemset: (1849510,) 	 Support: 120
# Itemset: (7230493,) 	 Support: 120
# Itemset: (6985672,) 	 Support: 120
# Itemset: (1650064,) 	 Support: 121
# Itemset: (7213643,) 	 Support: 121
# Itemset: (7222567,) 	 Support: 121
# Itemset: (7204426,) 	 Support: 121
# Itemset: (1477119,) 	 Support: 121
# Itemset: (1051120,) 	 Support: 121
# Itemset: (7228560,) 	 Support: 121
# Itemset: (7145636,) 	 Support: 121
# Itemset: (7092508,) 	 Support: 121
# Itemset: (695336,) 	 Support: 121
# Itemset: (7210909,) 	 Support: 121
# Itemset: (1944401,) 	 Support: 122
# Itemset: (7208398,) 	 Support: 122
# Itemset: (7204882,) 	 Support: 122
# Itemset: (7344859,) 	 Support: 122
# Itemset: (7003186,) 	 Support: 122
# Itemset: (7204880,) 	 Support: 123
# Itemset: (1909316,) 	 Support: 123
# Itemset: (7212663,) 	 Support: 123
# Itemset: (7362832,) 	 Support: 123
# Itemset: (7204903,) 	 Support: 123
# Itemset: (7325195,) 	 Support: 124
# Itemset: (7369636,) 	 Support: 124
# Itemset: (2067757,) 	 Support: 124
# Itemset: (7359427,) 	 Support: 124
# Itemset: (7015976,) 	 Support: 124
# Itemset: (7217672,) 	 Support: 124
# Itemset: (7225945,) 	 Support: 125
# Itemset: (2202690,) 	 Support: 125
# Itemset: (2449240,) 	 Support: 125
# Itemset: (7173101,) 	 Support: 125
# Itemset: (6994809,) 	 Support: 125
# Itemset: (7226854,) 	 Support: 125
# Itemset: (7228650,) 	 Support: 125
# Itemset: (7270729,) 	 Support: 125
# Itemset: (7360427,) 	 Support: 125
# Itemset: (7015776,) 	 Support: 125
# Itemset: (1051042,) 	 Support: 125
# Itemset: (1028714,) 	 Support: 125
# Itemset: (7237034,) 	 Support: 126
# Itemset: (7200218,) 	 Support: 126
# Itemset: (7163435,) 	 Support: 126
# Itemset: (7371807,) 	 Support: 126
# Itemset: (7216195,) 	 Support: 127
# Itemset: (7216630,) 	 Support: 127
# Itemset: (976180,) 	 Support: 127
# Itemset: (1719786,) 	 Support: 127
# Itemset: (6932933,) 	 Support: 127
# Itemset: (7381968,) 	 Support: 127
# Itemset: (7354181,) 	 Support: 128
# Itemset: (6988980,) 	 Support: 128
# Itemset: (748152,) 	 Support: 128
# Itemset: (7156262,) 	 Support: 128
# Itemset: (7204208,) 	 Support: 128
# Itemset: (1834279,) 	 Support: 128
# Itemset: (7226882,) 	 Support: 128
# Itemset: (7144240,) 	 Support: 129
# Itemset: (7342064,) 	 Support: 129
# Itemset: (7119211,) 	 Support: 129
# Itemset: (7347716,) 	 Support: 129
# Itemset: (7422638,) 	 Support: 129
# Itemset: (7134399,) 	 Support: 129
# Itemset: (7223447,) 	 Support: 129
# Itemset: (7203267,) 	 Support: 130
# Itemset: (7322202,) 	 Support: 130
# Itemset: (2435086,) 	 Support: 130
# Itemset: (7169212,) 	 Support: 130
# Itemset: (7228456,) 	 Support: 130
# Itemset: (2471674,) 	 Support: 130
# Itemset: (2401524,) 	 Support: 130
# Itemset: (7182628,) 	 Support: 130
# Itemset: (1067262,) 	 Support: 130
# Itemset: (788597,) 	 Support: 131
# Itemset: (7209266,) 	 Support: 131
# Itemset: (115772,) 	 Support: 131
# Itemset: (6962782,) 	 Support: 131
# Itemset: (7149510,) 	 Support: 131
# Itemset: (6982477,) 	 Support: 131
# Itemset: (7208194,) 	 Support: 131
# Itemset: (7223520,) 	 Support: 131
# Itemset: (6968173,) 	 Support: 131
# Itemset: (7216235,) 	 Support: 131
# Itemset: (2221675,) 	 Support: 131
# Itemset: (7368240,) 	 Support: 131
# Itemset: (7205525,) 	 Support: 131
# Itemset: (7210056,) 	 Support: 132
# Itemset: (7357183,) 	 Support: 132
# Itemset: (2403464,) 	 Support: 132
# Itemset: (7237499,) 	 Support: 132
# Itemset: (7359151,) 	 Support: 132
# Itemset: (7241040,) 	 Support: 133
# Itemset: (7362784,) 	 Support: 133
# Itemset: (7251611,) 	 Support: 133
# Itemset: (1699603,) 	 Support: 133
# Itemset: (7338612,) 	 Support: 133
# Itemset: (688385,) 	 Support: 133
# Itemset: (688385, 1024309) 	 Support: 68
# Itemset: (6926153,) 	 Support: 133
# Itemset: (2168309,) 	 Support: 133
# Itemset: (7354702,) 	 Support: 133
# Itemset: (516174,) 	 Support: 133
# Itemset: (1924285,) 	 Support: 134
# Itemset: (7218092,) 	 Support: 134
# Itemset: (6984012,) 	 Support: 134
# Itemset: (6992400,) 	 Support: 134
# Itemset: (7203499,) 	 Support: 134
# Itemset: (7014809,) 	 Support: 135
# Itemset: (7206215,) 	 Support: 135
# Itemset: (6987722,) 	 Support: 135
# Itemset: (7233843,) 	 Support: 135
# Itemset: (7383818,) 	 Support: 136
# Itemset: (1022218,) 	 Support: 136
# Itemset: (7227138,) 	 Support: 136
# Itemset: (1664376,) 	 Support: 136
# Itemset: (7367554,) 	 Support: 136
# Itemset: (1916319,) 	 Support: 136
# Itemset: (7336403,) 	 Support: 136
# Itemset: (7205841,) 	 Support: 137
# Itemset: (5103473,) 	 Support: 137
# Itemset: (7008686,) 	 Support: 137
# Itemset: (7206533,) 	 Support: 137
# Itemset: (1226553,) 	 Support: 137
# Itemset: (7322719,) 	 Support: 137
# Itemset: (7212229,) 	 Support: 137
# Itemset: (616496,) 	 Support: 137
# Itemset: (879666,) 	 Support: 137
# Itemset: (562953,) 	 Support: 138
# Itemset: (454171,) 	 Support: 138
# Itemset: (970015,) 	 Support: 138
# Itemset: (7006666,) 	 Support: 138
# Itemset: (7296063,) 	 Support: 139
# Itemset: (1413099,) 	 Support: 139
# Itemset: (7100827,) 	 Support: 139
# Itemset: (7229155,) 	 Support: 139
# Itemset: (7353822,) 	 Support: 139
# Itemset: (7362899,) 	 Support: 140
# Itemset: (1697622,) 	 Support: 140
# Itemset: (7002817,) 	 Support: 140
# Itemset: (7113355,) 	 Support: 140
# Itemset: (341003,) 	 Support: 140
# Itemset: (7167985,) 	 Support: 141
# Itemset: (2212569,) 	 Support: 141
# Itemset: (7338062,) 	 Support: 141
# Itemset: (7239959,) 	 Support: 141
# Itemset: (854560,) 	 Support: 141
# Itemset: (6982415,) 	 Support: 141
# Itemset: (7199112,) 	 Support: 141
# Itemset: (7168191,) 	 Support: 141
# Itemset: (7009580,) 	 Support: 142
# Itemset: (6992829,) 	 Support: 142
# Itemset: (2261842,) 	 Support: 142
# Itemset: (555410,) 	 Support: 142
# Itemset: (7227804,) 	 Support: 142
# Itemset: (7423210,) 	 Support: 142
# Itemset: (1860258,) 	 Support: 142
# Itemset: (7356107,) 	 Support: 143
# Itemset: (7003588,) 	 Support: 143
# Itemset: (7374313,) 	 Support: 143
# Itemset: (7226894,) 	 Support: 143
# Itemset: (7209235,) 	 Support: 143
# Itemset: (1772336,) 	 Support: 143
# Itemset: (7144613,) 	 Support: 144
# Itemset: (2145504,) 	 Support: 144
# Itemset: (7333290,) 	 Support: 144
# Itemset: (2059773,) 	 Support: 144
# Itemset: (7372924,) 	 Support: 144
# Itemset: (7193959,) 	 Support: 144
# Itemset: (7372119,) 	 Support: 145
# Itemset: (7012856,) 	 Support: 145
# Itemset: (7211736,) 	 Support: 145
# Itemset: (7006155,) 	 Support: 145
# Itemset: (7276090,) 	 Support: 145
# Itemset: (7005326,) 	 Support: 145
# Itemset: (7002532, 7005326) 	 Support: 70
# Itemset: (7114280,) 	 Support: 146
# Itemset: (6983187,) 	 Support: 146
# Itemset: (7227980,) 	 Support: 146
# Itemset: (7435278,) 	 Support: 146
# Itemset: (6954879,) 	 Support: 146
# Itemset: (6936543,) 	 Support: 146
# Itemset: (7262755,) 	 Support: 146
# Itemset: (7236481,) 	 Support: 147
# Itemset: (7217905,) 	 Support: 147
# Itemset: (7121225,) 	 Support: 147
# Itemset: (7014909,) 	 Support: 147
# Itemset: (977255,) 	 Support: 147
# Itemset: (1766254,) 	 Support: 147
# Itemset: (6967012,) 	 Support: 147
# Itemset: (1024309,) 	 Support: 148
# Itemset: (7270797,) 	 Support: 148
# Itemset: (7323848,) 	 Support: 148
# Itemset: (6928416,) 	 Support: 148
# Itemset: (7358739,) 	 Support: 148
# Itemset: (7161915,) 	 Support: 148
# Itemset: (7181107,) 	 Support: 148
# Itemset: (7206835,) 	 Support: 149
# Itemset: (7140246,) 	 Support: 149
# Itemset: (977373,) 	 Support: 149
# Itemset: (7340865,) 	 Support: 149
# Itemset: (2445341,) 	 Support: 149
# Itemset: (2145706,) 	 Support: 149
# Itemset: (7227120,) 	 Support: 149
# Itemset: (7312151,) 	 Support: 150
# Itemset: (7216424,) 	 Support: 150
# Itemset: (6990618,) 	 Support: 150
# Itemset: (7011148,) 	 Support: 150
# Itemset: (7215108,) 	 Support: 150
# Itemset: (7209383,) 	 Support: 151
# Itemset: (1907665,) 	 Support: 151
# Itemset: (1938820,) 	 Support: 151
# Itemset: (7227688,) 	 Support: 151
# Itemset: (1830892,) 	 Support: 151
# Itemset: (755154,) 	 Support: 152
# Itemset: (7224865,) 	 Support: 152
# Itemset: (7002708,) 	 Support: 152
# Itemset: (7195403,) 	 Support: 153
# Itemset: (7207424,) 	 Support: 153
# Itemset: (7200252,) 	 Support: 153
# Itemset: (6815483,) 	 Support: 153
# Itemset: (925532,) 	 Support: 153
# Itemset: (2463676,) 	 Support: 153
# Itemset: (2403398,) 	 Support: 153
# Itemset: (6980724,) 	 Support: 153
# Itemset: (7117519,) 	 Support: 153
# Itemset: (7008837,) 	 Support: 154
# Itemset: (7212626,) 	 Support: 154
# Itemset: (847897,) 	 Support: 154
# Itemset: (6980429,) 	 Support: 154
# Itemset: (1139544,) 	 Support: 155
# Itemset: (7205494,) 	 Support: 155
# Itemset: (7095100,) 	 Support: 156
# Itemset: (1172202,) 	 Support: 156
# Itemset: (7344696,) 	 Support: 156
# Itemset: (854022,) 	 Support: 156
# Itemset: (7277146,) 	 Support: 156
# Itemset: (7231198,) 	 Support: 157
# Itemset: (7209381,) 	 Support: 157
# Itemset: (733639,) 	 Support: 157
# Itemset: (7328143,) 	 Support: 157
# Itemset: (6971021,) 	 Support: 157
# Itemset: (6964013,) 	 Support: 157
# Itemset: (7131652,) 	 Support: 158
# Itemset: (6967201,) 	 Support: 158
# Itemset: (7369951,) 	 Support: 158
# Itemset: (7329077,) 	 Support: 158
# Itemset: (2016268,) 	 Support: 158
# Itemset: (1965837,) 	 Support: 159
# Itemset: (2100671,) 	 Support: 159
# Itemset: (7207770,) 	 Support: 159
# Itemset: (7241324,) 	 Support: 159
# Itemset: (7228955,) 	 Support: 159
# Itemset: (6953059,) 	 Support: 159
# Itemset: (6991033,) 	 Support: 160
# Itemset: (7219940,) 	 Support: 160
# Itemset: (2429724,) 	 Support: 160
# Itemset: (7337202,) 	 Support: 161
# Itemset: (7008576,) 	 Support: 161
# Itemset: (1782642,) 	 Support: 161
# Itemset: (7119575,) 	 Support: 161
# Itemset: (7001603,) 	 Support: 161
# Itemset: (2461586,) 	 Support: 161
# Itemset: (7341314,) 	 Support: 161
# Itemset: (7244635,) 	 Support: 161
# Itemset: (1915573,) 	 Support: 162
# Itemset: (7207401,) 	 Support: 162
# Itemset: (7231432,) 	 Support: 162
# Itemset: (736492,) 	 Support: 162
# Itemset: (7203765,) 	 Support: 163
# Itemset: (7145518,) 	 Support: 163
# Itemset: (7217164,) 	 Support: 163
# Itemset: (2391528,) 	 Support: 163
# Itemset: (7008288,) 	 Support: 163
# Itemset: (7352088,) 	 Support: 163
# Itemset: (7182367,) 	 Support: 163
# Itemset: (7005146,) 	 Support: 164
# Itemset: (7206427,) 	 Support: 164
# Itemset: (7003574,) 	 Support: 164
# Itemset: (7108417,) 	 Support: 164
# Itemset: (1913074,) 	 Support: 164
# Itemset: (853505,) 	 Support: 164
# Itemset: (7230838,) 	 Support: 165
# Itemset: (539691,) 	 Support: 165
# Itemset: (7161596,) 	 Support: 165
# Itemset: (7275384,) 	 Support: 165
# Itemset: (7012763,) 	 Support: 166
# Itemset: (142417,) 	 Support: 167
# Itemset: (2324361,) 	 Support: 167
# Itemset: (975330,) 	 Support: 167
# Itemset: (7324418,) 	 Support: 167
# Itemset: (7365581,) 	 Support: 167
# Itemset: (7225101,) 	 Support: 167
# Itemset: (7203698,) 	 Support: 168
# Itemset: (2449259,) 	 Support: 168
# Itemset: (7181293,) 	 Support: 168
# Itemset: (794061,) 	 Support: 168
# Itemset: (7373108,) 	 Support: 168
# Itemset: (7362407,) 	 Support: 168
# Itemset: (2170820,) 	 Support: 168
# Itemset: (7205302,) 	 Support: 168
# Itemset: (7218223,) 	 Support: 169
# Itemset: (7361026,) 	 Support: 169
# Itemset: (2261574,) 	 Support: 169
# Itemset: (7218317,) 	 Support: 169
# Itemset: (246698,) 	 Support: 170
# Itemset: (1206095,) 	 Support: 170
# Itemset: (7205823,) 	 Support: 171
# Itemset: (7210654,) 	 Support: 171
# Itemset: (6980508,) 	 Support: 171
# Itemset: (868800,) 	 Support: 171
# Itemset: (6978292,) 	 Support: 171
# Itemset: (1975736,) 	 Support: 171
# Itemset: (7353417,) 	 Support: 171
# Itemset: (7211460,) 	 Support: 171
# Itemset: (7008955,) 	 Support: 171
# Itemset: (7134760,) 	 Support: 172
# Itemset: (7224173,) 	 Support: 172
# Itemset: (7216285,) 	 Support: 172
# Itemset: (551669,) 	 Support: 173
# Itemset: (7117651,) 	 Support: 173
# Itemset: (7227517,) 	 Support: 173
# Itemset: (1438392,) 	 Support: 174
# Itemset: (1830310,) 	 Support: 174
# Itemset: (1182415,) 	 Support: 174
# Itemset: (1169745,) 	 Support: 174
# Itemset: (7089287,) 	 Support: 175
# Itemset: (7201458,) 	 Support: 175
# Itemset: (7337822,) 	 Support: 175
# Itemset: (6954462,) 	 Support: 175
# Itemset: (7382276,) 	 Support: 175
# Itemset: (7202750,) 	 Support: 176
# Itemset: (2072461,) 	 Support: 176
# Itemset: (7344810,) 	 Support: 176
# Itemset: (179993,) 	 Support: 177
# Itemset: (1507816,) 	 Support: 177
# Itemset: (7002532,) 	 Support: 177
# Itemset: (7011432,) 	 Support: 178
# Itemset: (1913633,) 	 Support: 178
# Itemset: (1769129,) 	 Support: 178
# Itemset: (954025,) 	 Support: 178
# Itemset: (7205942,) 	 Support: 178
# Itemset: (7426898,) 	 Support: 178
# Itemset: (1034678,) 	 Support: 179
# Itemset: (7374043,) 	 Support: 179
# Itemset: (7006177,) 	 Support: 179
# Itemset: (7234253,) 	 Support: 180
# Itemset: (6989957,) 	 Support: 180
# Itemset: (2253931,) 	 Support: 180
# Itemset: (1978505,) 	 Support: 180
# Itemset: (1910763,) 	 Support: 181
# Itemset: (2454428,) 	 Support: 181
# Itemset: (708426,) 	 Support: 181
# Itemset: (1836416,) 	 Support: 181
# Itemset: (7222086,) 	 Support: 181
# Itemset: (7358954,) 	 Support: 182
# Itemset: (7005678,) 	 Support: 182
# Itemset: (7270087,) 	 Support: 182
# Itemset: (7348807,) 	 Support: 183
# Itemset: (7384511,) 	 Support: 183
# Itemset: (6985785,) 	 Support: 183
# Itemset: (729751,) 	 Support: 183
# Itemset: (7320373,) 	 Support: 183
# Itemset: (5122747,) 	 Support: 183
# Itemset: (7009204,) 	 Support: 184
# Itemset: (7220879,) 	 Support: 184
# Itemset: (6999092,) 	 Support: 184
# Itemset: (7384229,) 	 Support: 184
# Itemset: (7209304,) 	 Support: 184
# Itemset: (7182257,) 	 Support: 185
# Itemset: (1213065,) 	 Support: 185
# Itemset: (7356390,) 	 Support: 186
# Itemset: (938139,) 	 Support: 187
# Itemset: (6952842,) 	 Support: 187
# Itemset: (966407,) 	 Support: 188
# Itemset: (1885992,) 	 Support: 188
# Itemset: (2483237,) 	 Support: 188
# Itemset: (7110702,) 	 Support: 189
# Itemset: (2362366,) 	 Support: 189
# Itemset: (6986607,) 	 Support: 189
# Itemset: (7003180,) 	 Support: 190
# Itemset: (6985183,) 	 Support: 191
# Itemset: (1292228,) 	 Support: 191
# Itemset: (7181153,) 	 Support: 192
# Itemset: (2135197,) 	 Support: 193
# Itemset: (7315474,) 	 Support: 193
# Itemset: (7370577,) 	 Support: 193
# Itemset: (7119201,) 	 Support: 194
# Itemset: (7234545,) 	 Support: 194
# Itemset: (7333681,) 	 Support: 194
# Itemset: (175742,) 	 Support: 194
# Itemset: (2205035,) 	 Support: 194
# Itemset: (7210697,) 	 Support: 194
# Itemset: (6980161,) 	 Support: 195
# Itemset: (7155901,) 	 Support: 195
# Itemset: (7201499,) 	 Support: 195
# Itemset: (7106013,) 	 Support: 195
# Itemset: (7346085,) 	 Support: 196
# Itemset: (6977268,) 	 Support: 196
# Itemset: (7212885,) 	 Support: 197
# Itemset: (1913956,) 	 Support: 198
# Itemset: (7217711,) 	 Support: 198
# Itemset: (2141019,) 	 Support: 198
# Itemset: (7003445,) 	 Support: 199
# Itemset: (7385801,) 	 Support: 199
# Itemset: (1962518,) 	 Support: 199
# Itemset: (7146427,) 	 Support: 200
# Itemset: (7112086,) 	 Support: 200
# Itemset: (662438,) 	 Support: 200
# Itemset: (7208864,) 	 Support: 201
# Itemset: (7005047,) 	 Support: 201
# Itemset: (7007543,) 	 Support: 201
# Itemset: (655438,) 	 Support: 201
# Itemset: (7311818,) 	 Support: 201
# Itemset: (6979227,) 	 Support: 201
# Itemset: (6983781,) 	 Support: 201
# Itemset: (7350481,) 	 Support: 202
# Itemset: (2402637,) 	 Support: 202
# Itemset: (2402637, 2427371) 	 Support: 91
# Itemset: (7205785,) 	 Support: 203
# Itemset: (1879020,) 	 Support: 203
# Itemset: (2046597,) 	 Support: 204
# Itemset: (2246109,) 	 Support: 204
# Itemset: (935602,) 	 Support: 204
# Itemset: (7273755,) 	 Support: 204
# Itemset: (7143297,) 	 Support: 204
# Itemset: (2034068,) 	 Support: 205
# Itemset: (6955116,) 	 Support: 205
# Itemset: (7130262,) 	 Support: 205
# Itemset: (7219719,) 	 Support: 205
# Itemset: (7354422,) 	 Support: 206
# Itemset: (7012179,) 	 Support: 207
# Itemset: (7235239,) 	 Support: 207
# Itemset: (7285126,) 	 Support: 207
# Itemset: (7008346,) 	 Support: 207
# Itemset: (7233446,) 	 Support: 207
# Itemset: (7186846,) 	 Support: 207
# Itemset: (7355287,) 	 Support: 208
# Itemset: (7004842,) 	 Support: 208
# Itemset: (1820150,) 	 Support: 208
# Itemset: (7163954,) 	 Support: 209
# Itemset: (6978956,) 	 Support: 209
# Itemset: (6961860,) 	 Support: 209
# Itemset: (7227600,) 	 Support: 209
# Itemset: (7204275,) 	 Support: 210
# Itemset: (2457471,) 	 Support: 210
# Itemset: (7015423,) 	 Support: 211
# Itemset: (7209602,) 	 Support: 211
# Itemset: (6930055,) 	 Support: 211
# Itemset: (7007507,) 	 Support: 211
# Itemset: (6921263,) 	 Support: 211
# Itemset: (7232090,) 	 Support: 212
# Itemset: (7371719,) 	 Support: 213
# Itemset: (7355817,) 	 Support: 214
# Itemset: (372266,) 	 Support: 214
# Itemset: (1935390,) 	 Support: 214
# Itemset: (6969441,) 	 Support: 214
# Itemset: (7242451,) 	 Support: 215
# Itemset: (7429487,) 	 Support: 215
# Itemset: (2241758,) 	 Support: 215
# Itemset: (1849698,) 	 Support: 216
# Itemset: (7339387,) 	 Support: 216
# Itemset: (7206628,) 	 Support: 216
# Itemset: (7233420,) 	 Support: 217
# Itemset: (6981154,) 	 Support: 217
# Itemset: (7229571,) 	 Support: 218
# Itemset: (7223296,) 	 Support: 219
# Itemset: (7269847,) 	 Support: 219
# Itemset: (7173335,) 	 Support: 219
# Itemset: (6996507,) 	 Support: 219
# Itemset: (1013753,) 	 Support: 219
# Itemset: (2373652,) 	 Support: 220
# Itemset: (7362658,) 	 Support: 220
# Itemset: (6961418,) 	 Support: 221
# Itemset: (7203701,) 	 Support: 221
# Itemset: (7104291,) 	 Support: 222
# Itemset: (1416008,) 	 Support: 222
# Itemset: (7209565,) 	 Support: 222
# Itemset: (7164481,) 	 Support: 222
# Itemset: (7127296,) 	 Support: 222
# Itemset: (7231388,) 	 Support: 222
# Itemset: (6980994,) 	 Support: 224
# Itemset: (6983553,) 	 Support: 224
# Itemset: (7350688,) 	 Support: 224
# Itemset: (7011525,) 	 Support: 224
# Itemset: (2024597,) 	 Support: 224
# Itemset: (2191728,) 	 Support: 225
# Itemset: (7214796,) 	 Support: 226
# Itemset: (7124135,) 	 Support: 226
# Itemset: (7338872,) 	 Support: 227
# Itemset: (6926823,) 	 Support: 227
# Itemset: (6983615,) 	 Support: 230
# Itemset: (2410353,) 	 Support: 230
# Itemset: (7004010,) 	 Support: 231
# Itemset: (6978179,) 	 Support: 232
# Itemset: (7008020,) 	 Support: 233
# Itemset: (2437242,) 	 Support: 233
# Itemset: (7372820,) 	 Support: 234
# Itemset: (2134867,) 	 Support: 235
# Itemset: (854731,) 	 Support: 235
# Itemset: (7360362,) 	 Support: 235
# Itemset: (7178342,) 	 Support: 235
# Itemset: (7116403,) 	 Support: 238
# Itemset: (7116403, 7367686) 	 Support: 68
# Itemset: (7230584,) 	 Support: 238
# Itemset: (7183402,) 	 Support: 238
# Itemset: (547158,) 	 Support: 239
# Itemset: (7366529,) 	 Support: 239
# Itemset: (7108122,) 	 Support: 240
# Itemset: (6841977,) 	 Support: 241
# Itemset: (708417,) 	 Support: 241
# Itemset: (183363,) 	 Support: 241
# Itemset: (2069563,) 	 Support: 242
# Itemset: (7367862,) 	 Support: 243
# Itemset: (7359893,) 	 Support: 245
# Itemset: (7001138,) 	 Support: 245
# Itemset: (583466,) 	 Support: 246
# Itemset: (7217479,) 	 Support: 246
# Itemset: (1547624,) 	 Support: 246
# Itemset: (950763,) 	 Support: 246
# Itemset: (7207018,) 	 Support: 248
# Itemset: (7212757,) 	 Support: 249
# Itemset: (7192163, 7212757) 	 Support: 95
# Itemset: (7096671,) 	 Support: 249
# Itemset: (1561311,) 	 Support: 250
# Itemset: (1903992,) 	 Support: 251
# Itemset: (6978895,) 	 Support: 251
# Itemset: (2449973,) 	 Support: 252
# Itemset: (7346837,) 	 Support: 254
# Itemset: (7214288,) 	 Support: 254
# Itemset: (6986292,) 	 Support: 254
# Itemset: (7362100,) 	 Support: 255
# Itemset: (2031062,) 	 Support: 255
# Itemset: (2414128,) 	 Support: 256
# Itemset: (1915872,) 	 Support: 256
# Itemset: (1900086,) 	 Support: 257
# Itemset: (2013629,) 	 Support: 257
# Itemset: (7217445,) 	 Support: 257
# Itemset: (6983891,) 	 Support: 257
# Itemset: (7114020,) 	 Support: 257
# Itemset: (7108281,) 	 Support: 257
# Itemset: (7258604,) 	 Support: 258
# Itemset: (7235475,) 	 Support: 258
# Itemset: (7241676,) 	 Support: 258
# Itemset: (5143720,) 	 Support: 258
# Itemset: (7066782,) 	 Support: 259
# Itemset: (6919338,) 	 Support: 259
# Itemset: (7210463,) 	 Support: 260
# Itemset: (2402342,) 	 Support: 260
# Itemset: (7209291,) 	 Support: 261
# Itemset: (6983466, 7209291) 	 Support: 80
# Itemset: (7005266,) 	 Support: 263
# Itemset: (1515505,) 	 Support: 263
# Itemset: (2453918,) 	 Support: 264
# Itemset: (7243246,) 	 Support: 265
# Itemset: (2016433,) 	 Support: 266
# Itemset: (1309256,) 	 Support: 267
# Itemset: (7380667,) 	 Support: 268
# Itemset: (2450023,) 	 Support: 269
# Itemset: (2060808,) 	 Support: 269
# Itemset: (7205739,) 	 Support: 270
# Itemset: (7000585, 7205739) 	 Support: 80
# Itemset: (584261,) 	 Support: 270
# Itemset: (6849640,) 	 Support: 270
# Itemset: (2034580, 6849640) 	 Support: 69
# Itemset: (7165701,) 	 Support: 272
# Itemset: (7348061,) 	 Support: 273
# Itemset: (6967076,) 	 Support: 274
# Itemset: (292357,) 	 Support: 274
# Itemset: (6988410,) 	 Support: 274
# Itemset: (7018256,) 	 Support: 274
# Itemset: (1884338,) 	 Support: 276
# Itemset: (7235412,) 	 Support: 276
# Itemset: (7380440,) 	 Support: 277
# Itemset: (479283,) 	 Support: 277
# Itemset: (7239011,) 	 Support: 278
# Itemset: (1711272,) 	 Support: 280
# Itemset: (7383314,) 	 Support: 282
# Itemset: (2006378,) 	 Support: 283
# Itemset: (2006378, 7204288) 	 Support: 66
# Itemset: (7347152,) 	 Support: 284
# Itemset: (7250718, 7307041) 	 Support: 81
# Itemset: (7246361, 7307041) 	 Support: 84
# Itemset: (7394938,) 	 Support: 285
# Itemset: (7394938, 7405577) 	 Support: 69
# Itemset: (7113605,) 	 Support: 285
# Itemset: (1089082, 7245814) 	 Support: 75
# Itemset: (1089082, 7364235) 	 Support: 76
# Itemset: (1089082, 7238085) 	 Support: 77
# Itemset: (2440343,) 	 Support: 285
# Itemset: (1428295,) 	 Support: 287
# Itemset: (7208568,) 	 Support: 287
# Itemset: (6919216,) 	 Support: 288
# Itemset: (7210895,) 	 Support: 289
# Itemset: (7205750,) 	 Support: 289
# Itemset: (2065975,) 	 Support: 290
# Itemset: (7000585,) 	 Support: 291
# Itemset: (7200537,) 	 Support: 292
# Itemset: (1007604,) 	 Support: 293
# Itemset: (1007604, 1561269) 	 Support: 91
# Itemset: (7097406,) 	 Support: 293
# Itemset: (7214891,) 	 Support: 294
# Itemset: (7218584,) 	 Support: 295
# Itemset: (7166625,) 	 Support: 296
# Itemset: (1321564,) 	 Support: 296
# Itemset: (1321564, 1796727) 	 Support: 73
# Itemset: (7263534,) 	 Support: 297
# Itemset: (7367686,) 	 Support: 297
# Itemset: (2333859,) 	 Support: 297
# Itemset: (7209865,) 	 Support: 298
# Itemset: (7336483,) 	 Support: 298
# Itemset: (1779759,) 	 Support: 299
# Itemset: (7341037,) 	 Support: 299
# Itemset: (7351462,) 	 Support: 302
# Itemset: (6983466,) 	 Support: 303
# Itemset: (1070456,) 	 Support: 304
# Itemset: (7239898,) 	 Support: 304
# Itemset: (7406871,) 	 Support: 305
# Itemset: (7238085, 7364235) 	 Support: 87
# Itemset: (7238085, 7245814) 	 Support: 88
# Itemset: (2295109,) 	 Support: 306
# Itemset: (2373589,) 	 Support: 306
# Itemset: (7008971,) 	 Support: 306
# Itemset: (7303224,) 	 Support: 306
# Itemset: (2066186,) 	 Support: 306
# Itemset: (1366225,) 	 Support: 307
# Itemset: (2428299,) 	 Support: 308
# Itemset: (2279145,) 	 Support: 311
# Itemset: (187197,) 	 Support: 313
# Itemset: (887741,) 	 Support: 315
# Itemset: (299916,) 	 Support: 315
# Itemset: (7309848,) 	 Support: 316
# Itemset: (7231595,) 	 Support: 317
# Itemset: (7218992,) 	 Support: 319
# Itemset: (2375869,) 	 Support: 321
# Itemset: (2411727,) 	 Support: 324
# Itemset: (7004891,) 	 Support: 324
# Itemset: (7231769,) 	 Support: 325
# Itemset: (2471322,) 	 Support: 326
# Itemset: (7302037,) 	 Support: 328
# Itemset: (7239712,) 	 Support: 329
# Itemset: (2450247,) 	 Support: 329
# Itemset: (7399188,) 	 Support: 330
# Itemset: (7399188, 7405577) 	 Support: 73
# Itemset: (7212697,) 	 Support: 333
# Itemset: (7198383, 7212697) 	 Support: 109
# Itemset: (7011397,) 	 Support: 334
# Itemset: (7223127,) 	 Support: 334
# Itemset: (7407604,) 	 Support: 336
# Itemset: (1713451,) 	 Support: 337
# Itemset: (1929742,) 	 Support: 339
# Itemset: (7357305,) 	 Support: 341
# Itemset: (7460800,) 	 Support: 341
# Itemset: (7373304,) 	 Support: 342
# Itemset: (6993450,) 	 Support: 343
# Itemset: (7100439,) 	 Support: 345
# Itemset: (1246021,) 	 Support: 346
# Itemset: (7237144,) 	 Support: 347
# Itemset: (7182267,) 	 Support: 347
# Itemset: (2226012,) 	 Support: 348
# Itemset: (6982714,) 	 Support: 350
# Itemset: (7009556,) 	 Support: 351
# Itemset: (1610999,) 	 Support: 352
# Itemset: (7176574,) 	 Support: 354
# Itemset: (6982892,) 	 Support: 356
# Itemset: (6960184,) 	 Support: 359
# Itemset: (1982352,) 	 Support: 360
# Itemset: (952537, 1982352) 	 Support: 79
# Itemset: (1796727,) 	 Support: 361
# Itemset: (6982689,) 	 Support: 362
# Itemset: (6982689, 7202830) 	 Support: 93
# Itemset: (7273966,) 	 Support: 362
# Itemset: (2430332,) 	 Support: 363
# Itemset: (7214595, 7221993) 	 Support: 75
# Itemset: (7214595, 7216672, 7221993) 	 Support: 67
# Itemset: (7216672, 7221993) 	 Support: 125
# Itemset: (2461867,) 	 Support: 366
# Itemset: (6964196,) 	 Support: 367
# Itemset: (7227124, 7228752) 	 Support: 95
# Itemset: (7228275, 7228752) 	 Support: 97
# Itemset: (6979014, 7233693) 	 Support: 70
# Itemset: (6978775, 7233693) 	 Support: 126
# Itemset: (7298557,) 	 Support: 370
# Itemset: (2446616,) 	 Support: 371
# Itemset: (1822118, 2446616) 	 Support: 81
# Itemset: (6977236, 6978798) 	 Support: 87
# Itemset: (6977236, 6979014) 	 Support: 94
# Itemset: (1044129,) 	 Support: 380
# Itemset: (7386746,) 	 Support: 381
# Itemset: (7313183,) 	 Support: 382
# Itemset: (7351198,) 	 Support: 382
# Itemset: (1056364,) 	 Support: 384
# Itemset: (7208694,) 	 Support: 384
# Itemset: (6982490, 7208694) 	 Support: 71
# Itemset: (7015755,) 	 Support: 387
# Itemset: (7351035,) 	 Support: 388
# Itemset: (7250718,) 	 Support: 392
# Itemset: (7202830,) 	 Support: 395
# Itemset: (1181652,) 	 Support: 398
# Itemset: (7164161,) 	 Support: 402
# Itemset: (6982490,) 	 Support: 404
# Itemset: (7228275,) 	 Support: 412
# Itemset: (7227124, 7228275) 	 Support: 136
# Itemset: (7329021,) 	 Support: 414
# Itemset: (7212421,) 	 Support: 418
# Itemset: (7203986, 7212421) 	 Support: 146
# Itemset: (1032277,) 	 Support: 420
# Itemset: (7205829,) 	 Support: 421
# Itemset: (7266809,) 	 Support: 423
# Itemset: (7215031,) 	 Support: 426
# Itemset: (952537,) 	 Support: 427
# Itemset: (7227124,) 	 Support: 427
# Itemset: (1751665,) 	 Support: 427
# Itemset: (7210031,) 	 Support: 429
# Itemset: (6983413, 7210031) 	 Support: 95
# Itemset: (7364235,) 	 Support: 432
# Itemset: (2471873,) 	 Support: 433
# Itemset: (431256,) 	 Support: 436
# Itemset: (7209583,) 	 Support: 438
# Itemset: (7197533, 7209583) 	 Support: 152
# Itemset: (7167006,) 	 Support: 444
# Itemset: (1924350, 7167006) 	 Support: 120
# Itemset: (7208725,) 	 Support: 446
# Itemset: (1971563,) 	 Support: 447
# Itemset: (7210026, 7226053) 	 Support: 69
# Itemset: (812485, 7226053) 	 Support: 95
# Itemset: (1083526,) 	 Support: 459
# Itemset: (1083526, 2139666) 	 Support: 75
# Itemset: (7243876,) 	 Support: 460
# Itemset: (1700710,) 	 Support: 462
# Itemset: (7004104,) 	 Support: 466
# Itemset: (6983413,) 	 Support: 468
# Itemset: (2211019,) 	 Support: 472
# Itemset: (7360081,) 	 Support: 473
# Itemset: (7198383,) 	 Support: 474
# Itemset: (7208914,) 	 Support: 478
# Itemset: (1747768,) 	 Support: 479
# Itemset: (7246361,) 	 Support: 479
# Itemset: (7219171, 7246361) 	 Support: 75
# Itemset: (7235333,) 	 Support: 480
# Itemset: (7245814,) 	 Support: 486
# Itemset: (916658,) 	 Support: 486
# Itemset: (916658, 1910662) 	 Support: 96
# Itemset: (6980324,) 	 Support: 487
# Itemset: (7346035,) 	 Support: 502
# Itemset: (7212377,) 	 Support: 505
# Itemset: (610989,) 	 Support: 512
# Itemset: (7405577,) 	 Support: 516
# Itemset: (7212621,) 	 Support: 521
# Itemset: (758856,) 	 Support: 522
# Itemset: (7207945,) 	 Support: 526
# Itemset: (2050326,) 	 Support: 530
# Itemset: (2050326, 2154456) 	 Support: 84
# Itemset: (2427371,) 	 Support: 532
# Itemset: (1334685,) 	 Support: 534
# Itemset: (812485,) 	 Support: 536
# Itemset: (812485, 7210026) 	 Support: 80
# Itemset: (1561269,) 	 Support: 539
# Itemset: (1302097,) 	 Support: 543
# Itemset: (1687470,) 	 Support: 544
# Itemset: (2063743,) 	 Support: 546
# Itemset: (7129452,) 	 Support: 551
# Itemset: (995573, 7129452) 	 Support: 105
# Itemset: (6854466, 7013781) 	 Support: 73
# Itemset: (2154456, 7013781) 	 Support: 155
# Itemset: (7366766,) 	 Support: 560
# Itemset: (7192163,) 	 Support: 573
# Itemset: (2034580,) 	 Support: 575
# Itemset: (7242788,) 	 Support: 575
# Itemset: (2331878, 7242788) 	 Support: 92
# Itemset: (2242389,) 	 Support: 577
# Itemset: (2397552,) 	 Support: 582
# Itemset: (7012459,) 	 Support: 586
# Itemset: (995573,) 	 Support: 589
# Itemset: (847564,) 	 Support: 596
# Itemset: (7200852, 7213375, 7217369) 	 Support: 78
# Itemset: (7200852, 7204288, 7213375, 7217369) 	 Support: 68
# Itemset: (7200852, 7204288, 7213375) 	 Support: 104
# Itemset: (7213375, 7217369) 	 Support: 153
# Itemset: (7204288, 7213375, 7217369) 	 Support: 99
# Itemset: (7204288, 7213375) 	 Support: 197
# Itemset: (7286419,) 	 Support: 605
# Itemset: (7214595, 7218097) 	 Support: 69
# Itemset: (7214595, 7216672) 	 Support: 187
# Itemset: (7185985,) 	 Support: 649
# Itemset: (7225854,) 	 Support: 658
# Itemset: (7214789, 7225854) 	 Support: 66
# Itemset: (5191913,) 	 Support: 667
# Itemset: (6978775, 6978798) 	 Support: 116
# Itemset: (6978775, 6978798, 6979014) 	 Support: 84
# Itemset: (6978798, 6979014) 	 Support: 196
# Itemset: (2139666,) 	 Support: 683
# Itemset: (7001178,) 	 Support: 687
# Itemset: (7200852, 7217369) 	 Support: 142
# Itemset: (7200852, 7204288, 7217369) 	 Support: 96
# Itemset: (7204288, 7217369) 	 Support: 189
# Itemset: (383565,) 	 Support: 701
# Itemset: (7214789,) 	 Support: 708
# Itemset: (379525,) 	 Support: 717
# Itemset: (379525, 1822118) 	 Support: 112
# Itemset: (5126500,) 	 Support: 717
# Itemset: (7210026,) 	 Support: 725
# Itemset: (866305,) 	 Support: 726
# Itemset: (1821681,) 	 Support: 732
# Itemset: (879335,) 	 Support: 741
# Itemset: (1924350, 7283875) 	 Support: 69
# Itemset: (1822118, 7283875) 	 Support: 88
# Itemset: (1033897, 1736696) 	 Support: 70
# Itemset: (1736696, 2033028) 	 Support: 72
# Itemset: (2024828,) 	 Support: 766
# Itemset: (2154456, 2331878) 	 Support: 78
# Itemset: (1924350, 2331878) 	 Support: 105
# Itemset: (1822118, 2331878) 	 Support: 106
# Itemset: (7219171,) 	 Support: 805
# Itemset: (6830067,) 	 Support: 809
# Itemset: (1822118, 2154456) 	 Support: 87
# Itemset: (2154456, 6875648) 	 Support: 93
# Itemset: (6830215,) 	 Support: 816
# Itemset: (1822118, 6830215) 	 Support: 68
# Itemset: (7216672,) 	 Support: 823
# Itemset: (7216672, 7218097) 	 Support: 95
# Itemset: (1910662,) 	 Support: 837
# Itemset: (1910662, 2033028) 	 Support: 95
# Itemset: (6854466,) 	 Support: 842
# Itemset: (1822118, 6854466) 	 Support: 93
# Itemset: (6979014,) 	 Support: 851
# Itemset: (6978775, 6979014) 	 Support: 269
# Itemset: (6978775,) 	 Support: 862
# Itemset: (862927, 1924350) 	 Support: 71
# Itemset: (862927, 1822118) 	 Support: 80
# Itemset: (7121410,) 	 Support: 886
# Itemset: (7197533,) 	 Support: 904
# Itemset: (942687, 1924350) 	 Support: 97
# Itemset: (942687, 1822118) 	 Support: 118
# Itemset: (7099912,) 	 Support: 944
# Itemset: (7200852,) 	 Support: 953
# Itemset: (7200852, 7204288) 	 Support: 225
# Itemset: (7203986,) 	 Support: 985
# Itemset: (2355580,) 	 Support: 998
# Itemset: (1822118, 2355580) 	 Support: 96
# Itemset: (1603229,) 	 Support: 1014
# Itemset: (7206622,) 	 Support: 1027
# Itemset: (2033028, 7218097) 	 Support: 71
# Itemset: (1769570, 2033028) 	 Support: 96
# Itemset: (1033897, 2033028) 	 Support: 122
# Itemset: (6999401,) 	 Support: 1054
# Itemset: (1769570,) 	 Support: 1098
# Itemset: (1033897, 1769570) 	 Support: 168
# Itemset: (1924350, 6875648) 	 Support: 72
# Itemset: (1822118, 6875648) 	 Support: 99
# Itemset: (7204288,) 	 Support: 1191
# Itemset: (1033897,) 	 Support: 1250
# Itemset: (1033897, 7218097) 	 Support: 75
# Itemset: (1924350,) 	 Support: 1359
# Itemset: (1822118, 1924350) 	 Support: 150
# Itemset: (7218097,) 	 Support: 1504
# Itemset: (7253075,) 	 Support: 1544
# Itemset: (1822118,) 	 Support: 1880

# %%
# generate association rules
min_confidence = 0.5  # minimum confidence threshold, when Antecedent appears, ther is 50% chance that Consequent also appears
rules = pyfpgrowth.generate_association_rules(
    frequent_itemsets,
    min_confidence
)
#sort rules by its confidence 
sorted_rules = dict(sorted(rules.items(), key=lambda x: x[1][1], reverse=True))

# %%
# print the association rules
for antecedent, consequent in sorted_rules.items():
    consequence, confidence = consequent
    print('Antecedent: {} => Consequent: {} \t Confidence: {}'.format(
        antecedent, consequence, confidence))
# Out:
# Antecedent: (7214595, 7221993) => Consequent: (7216672,) 	 Confidence: 0.8933333333333333
# Antecedent: (7200852, 7213375, 7217369) => Consequent: (7204288,) 	 Confidence: 0.8717948717948718
# Antecedent: (1001612,) => Consequent: (2461867,) 	 Confidence: 0.8272727272727273
# Antecedent: (6978775, 6978798) => Consequent: (6979014,) 	 Confidence: 0.7241379310344828
# Antecedent: (7200852, 7204288, 7217369) => Consequent: (7213375,) 	 Confidence: 0.7083333333333334
# Antecedent: (7204288, 7213375, 7217369) => Consequent: (7200852,) 	 Confidence: 0.6868686868686869
# Antecedent: (7200852, 7217369) => Consequent: (7204288,) 	 Confidence: 0.676056338028169
# Antecedent: (7200852, 7204288, 7213375) => Consequent: (7217369,) 	 Confidence: 0.6538461538461539
# Antecedent: (7213375, 7217369) => Consequent: (7204288,) 	 Confidence: 0.6470588235294118
# Antecedent: (7216672, 7221993) => Consequent: (7214595,) 	 Confidence: 0.536
# Antecedent: (688385,) => Consequent: (1024309,) 	 Confidence: 0.5112781954887218
# Antecedent: (7204288, 7217369) => Consequent: (7200852,) 	 Confidence: 0.5079365079365079
# Antecedent: (7204288, 7213375) => Consequent: (7217369,) 	 Confidence: 0.5025380710659898

# %% [markdown]
# ### 3.Business Insight <a id="bi"></a>

# %% [markdown]
# 1. The top 13 association rules mainly comes from 4 product_type and sports: (ELASTIC BAND, PILATES), (BACKPACK, MOUNTAIN), (KICK SCOOTER CO, URBAN), (ELASTIC, BODYBUILDING), (BATTERY, MOUNTAIN). This may indicate that customers buying these type of products have higher tendency to buy similar product. When these customers are searching or adding these products into cart, we can recommend related products to them based on our association rules.
#
#
# 2. We can also lauch promotional campaigns to encourage customers buy more products. For example, we can offer a discount on a complementary product if a customer buys a primary product.

# %%
#To easily identify sku_idr_sku belongs to which product_type and sports for interpretation, we can slighlty change the for loop
num = 1
for antecedent, consequent in sorted_rules.items():
    antecedent_list = list(antecedent)
    antecedent_names = []
    consequent_name = consequent[0]
    consequent_confidence = consequent[1]
    
    for sku_idr_sku in antecedent_list:
        sku_info = df.loc[df['sku_idr_sku'] == sku_idr_sku, ['product_type', 'sports']].iloc[0]
        sku_name = f"{sku_idr_sku} ({sku_info['product_type']}, {sku_info['sports']})"
        antecedent_names.append(sku_name)
    
    antecedent_names = ', '.join(antecedent_names)
    consequent_name = f"{consequent_name} ({df.loc[df['sku_idr_sku'] == consequent_name, 'product_type'].iloc[0]}, {df.loc[df['sku_idr_sku'] == consequent_name, 'sports'].iloc[0]})"
    
    print('{}. Antecedent: {} => Consequent: {} \t Confidence: {}'.format(
        num,antecedent_names, consequent_name, consequent_confidence))
    num+=1
# Out:
# 1. Antecedent: 7214595 (ELASTIC BAND, PILATES), 7221993 (ELASTIC BAND, PILATES) => Consequent: (7216672,) (ELASTIC BAND, PILATES) 	 Confidence: 0.8933333333333333
# 2. Antecedent: 7200852 (BACKPACK, MOUNTAIN), 7213375 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7204288,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.8717948717948718
# 3. Antecedent: 1001612 (KICK SCOOTER CO, URBAN) => Consequent: (2461867,) (SCOOTER, URBAN) 	 Confidence: 0.8272727272727273
# 4. Antecedent: 6978775 (ELASTIC, BODYBUILDING), 6978798 (ELASTIC, BODYBUILDING) => Consequent: (6979014,) (ELASTIC, BODYBUILDING) 	 Confidence: 0.7241379310344828
# 5. Antecedent: 7200852 (BACKPACK, MOUNTAIN), 7204288 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7213375,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.7083333333333334
# 6. Antecedent: 7204288 (BACKPACK, MOUNTAIN), 7213375 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7200852,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.6868686868686869
# 7. Antecedent: 7200852 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7204288,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.676056338028169
# 8. Antecedent: 7200852 (BACKPACK, MOUNTAIN), 7204288 (BACKPACK, MOUNTAIN), 7213375 (BACKPACK, MOUNTAIN) => Consequent: (7217369,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.6538461538461539
# 9. Antecedent: 7213375 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7204288,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.6470588235294118
# 10. Antecedent: 7216672 (ELASTIC BAND, PILATES), 7221993 (ELASTIC BAND, PILATES) => Consequent: (7214595,) (ELASTIC BAND, PILATES) 	 Confidence: 0.536
# 11. Antecedent: 688385 (BATTERY, MOUNTAIN) => Consequent: (1024309,) (BATTERY, MOUNTAIN) 	 Confidence: 0.5112781954887218
# 12. Antecedent: 7204288 (BACKPACK, MOUNTAIN), 7217369 (BACKPACK, MOUNTAIN) => Consequent: (7200852,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.5079365079365079
# 13. Antecedent: 7204288 (BACKPACK, MOUNTAIN), 7213375 (BACKPACK, MOUNTAIN) => Consequent: (7217369,) (BACKPACK, MOUNTAIN) 	 Confidence: 0.5025380710659898

# %% [markdown]
# ### 4.Limitation <a id="l"></a>

# %% [markdown]
# 1. Without more granular product categorization, it's hard to know the difference between antecedent product and consequent product and find out possible reasons why customers buy these products together.
#
#
# 2. The association rules we find still need to be validated becuase there might have chance to encounter Simpson's Paradox, which means the association rules may be influenced by the presence of ther confunding factors. To validate the association rules, we can perform A/B test on the website to test whether these rules help to increase basket size.
#
#
# 3. The hyperparameters such as minimum support and minimum confidence are based on my own assumption, so it may be different from the real business scenario.
